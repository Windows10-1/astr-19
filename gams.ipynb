# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.gumbel(size=1000)

plt.hist(x,bins=100, alpha=0.5, edgecolor = "black")
plt.ylabel("# per bin")
plt.xlabel("x")
plt.savefig("histogram_gams.pdf",bbox_inches="tight",facecolor="grey")
