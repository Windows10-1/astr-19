# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.uniform(0,1,size=1000)
#I dont need to put this in but i totally didn't just waste 30ish mins using various numpy random INT commands, forgetting what an int actually... is. 

plt.hist(x,bins=100, alpha=0.5, edgecolor = "black")
plt.ylabel("# per bin")
plt.xlabel("x")
plt.savefig("histograms.pdf",bbox_inches="tight",facecolor="grey")
