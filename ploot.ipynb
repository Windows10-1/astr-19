# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,1,100)
y = np.exp(x)
plt.plot(x,y)
plt.xlabel("Time (ms)")
plt.ylabel("Awesomeness")
plt.show()
plt.savefig("ploot.pdf",bbox_inches="tight",dpi=600)
